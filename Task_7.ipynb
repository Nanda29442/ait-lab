# %% [markdown]
# <a href="https://colab.research.google.com/github/Nanda29442/ait-lab/blob/main/Task_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Monkey = "window"
box = "window"
print("Monkey walks to box")
print("Monkey pushes box under bananas")
box = "under banana"
print("monkey climbs box")
banana = True
print("Goal achieved:",banana)
# Out:
# Monkey walks to box
# Monkey pushes box under bananas
# monkey climbs box
# Goal achieved: True
